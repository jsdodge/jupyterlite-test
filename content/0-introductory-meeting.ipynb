# %% [markdown]
# # Welcome to PHYS 132!
#
# This is a test notebook to introduce you to the Jupyter notebook interface. You will also use it to practice exporting a Jupyter notebook to PDF for assessment.
#
# &#x1F4CC; *Note*:
# * Sections that are enclosed by horizontal lines and begin with the &#x27A1; symbol indicate activities that require your response.
# * The alert flag &#x1F6A9; indicates an important point that merits your attention.

# %% [markdown]
# ## Jupyter notebooks are composed of cells
#
# A Jupyter notebook is a sequence of cells that can include formatted text and computer code. The text you are reading is contained in a **Markdown** cell, which refers to the formatting language that Jupyter uses. The cell below is a **Code** cell, which contains executable computer code. Notice that the menubar above has a field that indicates the type of cell that is currently selected. Select this cell, then select the cell below it to see how it changes. Next, **execute** the code cell below by selecting it and pressing **Shift-Enter**. (If you encounter a **Select Kernel** pop-up window, choose **Select**.)

# %%
print("hello, world")

# %% [markdown]
# ## Jupyter uses Markdown for formatting
#
# **Double-click on this cell** to see how the text is formatted.
#
# Jupyter uses the [Markdown markup language](https://www.markdownguide.org/) for formatting. We will provide you with guidance on how to use this formatting language for your notebooks. It is designed to be easy to learn and use.
#
# To return to the formatted view, press **Shift-Enter**.

# %% [markdown]
# ## Exercise 1: Modify this Markdown cell
#
# ---
#
# &#x27A1; Modify this cell to display your lab station label and the names of your group members.
#
# **Station 42B**
# 1. Willie Maykitt
# 2. Betty Wont
# 3. Justin Time
#
# ---

# %% [markdown]
# ## Exercise 2: Export this notebook to PDF and upload files to Crowdmark
#
# ---
# &#x27A1; After completing Exercise 1, follow the steps below to export your notebook to PDF for review.
#
# 1. Verify all of the output of the completed notebook and ensure that all of the Markdown cells show the rendered output instead of the raw Markdown text.
# 2. From the `File` menu, select `Save and Export Notebook As`, then `HTML`. This will generate a HTML file and download it to your **Downloads** folder.
# 3. Open the HTML file to verify that it appears as you expect.
# 4. Press `CTRL-P`.
# 5. Choose `Microsoft Print to PDF` in the `Printer` menu.
# 6. Select `Print` and save the PDF in the same folder as this Jupyter notebook. Use the same file name as your notebook, except for the `.ipynb` extension.
# 7. Open the link to **Crowdmark** from within the **Modules** section of Canvas and select the members of your group for the **Introductory meeting** assignment.
# 8. Upload the PDF output *and* the `.ipynb` file to Crowdmark. We will refer to the `.ipynb` file if we encounter any issues in the PDF output.
# 9. Verify that the PDF appears as you expect in Crowdmark.
# 10. Verify that the .ipynb file is attached.
#
# ---
